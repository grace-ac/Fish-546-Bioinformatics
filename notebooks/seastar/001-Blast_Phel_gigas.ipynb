# %%
pwd
# Out:
# 'C:\\Users\\rhondae\\Documents\\Github\\Fish-546-Bioinformatics\\notebooks\\Seastar'

# %% [markdown]
# Making database

# %%
cd C:/Users/rhondae/Documents/Github/Fish-546-Bioinformatics
# Out:
# C:\Users\rhondae\Documents\Github\Fish-546-Bioinformatics

# %%
# !C:/Users/rhondae/Desktop/blast-2.5.0+/bin/makeblastdb \
-in data/seastar/Merge_phelDEG1.fasta \
-dbtype nucl \
-out analyses/seastar/Phel_DEG_db
# Out:
# Building a new DB, current time: 10/28/2016 15:29:08
# New DB name:   C:\Users\rhondae\Documents\Github\Fish-546-Bioinformatics\analyses\seastar\Phel_DEG_db
# New DB title:  data/seastar/Merge_phelDEG1.fasta
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 3773 sequences in 1.99414 seconds.

# %%
# !head data/seastar/Galaxy32-[Tabular-to-FASTA_on_data_27].fasta
# Out:
# >Phel_contig_10
# ...
# >Phel_contig_10001
# ...
# >Phel_contig_10005
# ...
# >Phel_contig_10010
# ...
# >Phel_contig_10013
# ...

# %%
# !C:/Users/rhondae/Desktop/blast-2.5.0+/bin/blastx \
-query C:/Users/rhondae/Documents/Github/Fish-546-Bioinformatics/data/classproject/contigs.fasta.transdecoder.pep/contigs.fasta.transdecoder.pep \
-db analyses/seastar/Phel_DEG_db \
-evalue 1e-5 \
-max_target_seqs 1 \
-max_hsps 1 \
-outfmt 6 \
-num_threads 16 \
> analyses/seastar/blastoutput.txt
# Out:
# BLAST Database error: No alias or index file found for protein database [analyses\seastar\Phel_DEG_db] in search path [C:\Users\rhondae\Documents\Github\Fish-546-Bioinformatics;;]
