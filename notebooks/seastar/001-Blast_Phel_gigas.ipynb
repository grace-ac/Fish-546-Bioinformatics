# %%
pwd
# Out:
# 'C:\\Users\\rhondae\\Documents\\Github\\Fish-546-Bioinformatics\\notebooks\\seastar'

# %%
cd C:/Users/rhondae/Documents/Github/Fish-546-Bioinformatics
# Out:
# C:\Users\rhondae\Documents\Github\Fish-546-Bioinformatics

# %% [markdown]
# Creating database

# %%
# !C:/Users/rhondae/Desktop/blast-2.5.0+/bin/makeblastdb \
-in data/seastar/Merge_phelDEG1.fasta \
-dbtype nucl \
-out analyses/seastar/Phel_DEG_db
# Out:
# Building a new DB, current time: 10/28/2016 20:56:17
# New DB name:   C:\Users\rhondae\Documents\Github\Fish-546-Bioinformatics\analyses\seastar\Phel_DEG_db
# New DB title:  data/seastar/Merge_phelDEG1.fasta
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 3773 sequences in 2.64752 seconds.

# %%
# !head data/seastar/Merge_phelDEG1.fasta
# Out:
# >Phel_contig_10
# ...
# >Phel_contig_10001
# ...
# >Phel_contig_10005
# ...
# >Phel_contig_10010
# ...
# >Phel_contig_10013
# ...

# %%
Blasting _C.gigas_ transcriptome against _P. helianthoides_ differentially expressed genes

# %%
# !C:/Users/rhondae/Desktop/blast-2.5.0+/bin/blastn \
-query data/seastar/Fastafile_Microarray.txt \
-db analyses/seastar/Phel_DEG_db \
-evalue 1e-5 \
-max_target_seqs 1 \
-max_hsps 1 \
-outfmt 6 \
-num_threads 16 \
> analyses/seastar/blastoutput1.txt
# Out:
# FASTA-Reader: Ignoring invalid residues at position(s): On line 2: 2-3, 7
